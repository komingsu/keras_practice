# %% [markdown]
# * PAPER - AN IMAGE IS WORTH 16X16 WORDS : TRANSFORMERS FOR IMAGE RECOGNITION AT SCALE - [PDF](https://arxiv.org/pdf/2010.11929.pdf)
# * PAPER - Vision Transformer for Small-Size Datasets - [PDF](https://arxiv.org/pdf/2112.13492v1.pdf)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 준비

# %% [markdown]
# ## 라이브러리 호출

# %%
import math
import numpy as np
import tensorflow as tf
from tensorflow import keras
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
from tensorflow.keras import layers

# %% [markdown]
# ## 데이터

# %%
NUM_CLASSES = 100
INPUT_SHAPE = (32, 32, 3)

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (50000, 32, 32, 3) - y_train shape: (50000, 1)
# x_test shape: (10000, 32, 32, 3) - y_test shape: (10000, 1)

# %% [markdown]
# ## 하이퍼 파라미터

# %%
# DATA
BUFFER_SIZE = 512
BATCH_SIZE = 64

# AUGMENTATION
IMAGE_SIZE = 72
PATCH_SIZE = 6
NUM_PATCHES = (IMAGE_SIZE // PATCH_SIZE) ** 2

# OPTIMIZER
LEARNING_RATE = 0.001
WEIGHT_DECAY = 0.0001

# TRAINING
EPOCHS = 50

# ARCHITECTURE
LAYER_NORM_EPS = 1e-6
TRANSFORMER_LAYERS = 8
PROJECTION_DIM = 64
NUM_HEADS = 4
TRANSFORMER_UNITS = [PROJECTION_DIM * 2,PROJECTION_DIM,]
MLP_HEAD_UNITS = [2048, 1024]

# %% [markdown]
# ## 증강

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)
data_augmentation.layers[0].adapt(x_train)

# %% [markdown]
# # 모델

# %% [markdown]
# ## Shifted Patch Tokenization

# %%
class ShiftedPatchTokenization(layers.Layer):
    def __init__(
        self,
        image_size=IMAGE_SIZE,
        patch_size=PATCH_SIZE,
        num_patches=NUM_PATCHES,
        projection_dim=PROJECTION_DIM,
        vanilla=False,
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.vanilla = vanilla  # Flag to swtich to vanilla patch extractor
        self.image_size = image_size
        self.patch_size = patch_size
        self.half_patch = patch_size // 2
        self.flatten_patches = layers.Reshape((num_patches, -1))
        self.projection = layers.Dense(units=projection_dim)
        self.layer_norm = layers.LayerNormalization(epsilon=LAYER_NORM_EPS)

    def crop_shift_pad(self, images, mode):
        # Build the diagonally shifted images
        if mode == "left-up":
            crop_height = self.half_patch
            crop_width = self.half_patch
            shift_height = 0
            shift_width = 0
        elif mode == "left-down":
            crop_height = 0
            crop_width = self.half_patch
            shift_height = self.half_patch
            shift_width = 0
        elif mode == "right-up":
            crop_height = self.half_patch
            crop_width = 0
            shift_height = 0
            shift_width = self.half_patch
        else:
            crop_height = 0
            crop_width = 0
            shift_height = self.half_patch
            shift_width = self.half_patch

        # Crop the shifted images and pad them
        crop = tf.image.crop_to_bounding_box(
            images,
            offset_height=crop_height,
            offset_width=crop_width,
            target_height=self.image_size - self.half_patch,
            target_width=self.image_size - self.half_patch,
        )
        shift_pad = tf.image.pad_to_bounding_box(
            crop,
            offset_height=shift_height,
            offset_width=shift_width,
            target_height=self.image_size,
            target_width=self.image_size,
        )
        return shift_pad

    def call(self, images):
        if not self.vanilla:
            # Concat the shifted images with the original image
            images = tf.concat(
                [
                    images,
                    self.crop_shift_pad(images, mode="left-up"),
                    self.crop_shift_pad(images, mode="left-down"),
                    self.crop_shift_pad(images, mode="right-up"),
                    self.crop_shift_pad(images, mode="right-down"),
                ],
                axis=-1,
            )
        # Patchify the images and flatten it
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        flat_patches = self.flatten_patches(patches)
        if not self.vanilla:
            # Layer normalize the flat patches and linearly project it
            tokens = self.layer_norm(flat_patches)
            tokens = self.projection(tokens)
        else:
            # Linearly project the flat patches
            tokens = self.projection(flat_patches)
        return (tokens, patches)

# %% [markdown]
# ### Sample

# %%
# Get a random image from the training dataset
# and resize the image
image = x_train[np.random.choice(range(x_train.shape[0]))]
resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(IMAGE_SIZE, IMAGE_SIZE)
)

# Vanilla patch maker: This takes an image and divides into
# patches as in the original ViT paper
(token, patch) = ShiftedPatchTokenization(vanilla=True)(resized_image / 255.0)
(token, patch) = (token[0], patch[0])
n = patch.shape[0]
count = 1
plt.figure(figsize=(4, 4))
print("Vanilla patch")
for row in range(n):
    for col in range(n):
        plt.subplot(n, n, count)
        count = count + 1
        image = tf.reshape(patch[row][col], (PATCH_SIZE, PATCH_SIZE, 3))
        plt.imshow(image)
        plt.axis("off")
plt.show()

# Shifted Patch Tokenization: This layer takes the image, shifts it
# diagonally and then extracts patches from the concatinated images
(token, patch) = ShiftedPatchTokenization(vanilla=False)(resized_image / 255.0)
(token, patch) = (token[0], patch[0])
n = patch.shape[0]
shifted_images = ["ORIGINAL", "LEFT-UP", "LEFT-DOWN", "RIGHT-UP", "RIGHT-DOWN"]
for index, name in enumerate(shifted_images):
    print(name)
    count = 1
    plt.figure(figsize=(4, 4))
    for row in range(n):
        for col in range(n):
            plt.subplot(n, n, count)
            count = count + 1
            image = tf.reshape(patch[row][col], (PATCH_SIZE, PATCH_SIZE, 5 * 3))
            plt.imshow(image[..., 3 * index : 3 * index + 3])
            plt.axis("off")
    plt.show()
# Out:
# Vanilla patch
# ORIGINAL
# LEFT-UP
# LEFT-DOWN
# RIGHT-UP
# RIGHT-DOWN

# %% [markdown]
# ## Patch Encoding 층

# %%
class PatchEncoder(layers.Layer):
    def __init__(
        self, num_patches=NUM_PATCHES, projection_dim=PROJECTION_DIM, **kwargs
    ):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.position_embedding = layers.Embedding( input_dim=num_patches, output_dim=projection_dim)
        self.positions = tf.range(start=0, limit=self.num_patches, delta=1)

    def call(self, encoded_patches):
        encoded_positions = self.position_embedding(self.positions)
        encoded_patches = encoded_patches + encoded_positions
        return encoded_patches

# %% [markdown]
# ## MHA LSA

# %%
class MultiHeadAttentionLSA(tf.keras.layers.MultiHeadAttention):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        # The trainable temperature term. The initial value is
        # the square root of the key dimension.
        self.tau = tf.Variable(math.sqrt(float(self._key_dim)), trainable=True)

    def _compute_attention(self, query, key, value, attention_mask=None, training=None):
        query = tf.multiply(query, 1.0 / self.tau)
        attention_scores = tf.einsum(self._dot_product_equation, key, query)
        attention_scores = self._masked_softmax(attention_scores, attention_mask)
        attention_scores_dropout = self._dropout_layer(
            attention_scores, training=training
        )
        attention_output = tf.einsum(
            self._combine_equation, attention_scores_dropout, value
        )
        return attention_output, attention_scores

# %% [markdown]
# ## MLP

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

diag_attn_mask = 1 - tf.eye(NUM_PATCHES)
diag_attn_mask = tf.cast([diag_attn_mask], dtype=tf.int8)

# %% [markdown]
# ## Build Model

# %%
def create_vit_classifier(vanilla=False):
    inputs = layers.Input(shape=INPUT_SHAPE)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    (tokens, _) = ShiftedPatchTokenization(vanilla=vanilla)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder()(tokens)

    # Create multiple layers of the Transformer block.
    for _ in range(TRANSFORMER_LAYERS):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        if not vanilla:
            attention_output = MultiHeadAttentionLSA(
                num_heads=NUM_HEADS, key_dim=PROJECTION_DIM, dropout=0.1
            )(x1, x1, attention_mask=diag_attn_mask)
        else:
            attention_output = layers.MultiHeadAttention(
                num_heads=NUM_HEADS, key_dim=PROJECTION_DIM, dropout=0.1
            )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=TRANSFORMER_UNITS, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=MLP_HEAD_UNITS, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(NUM_CLASSES)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %% [markdown]
# ## warmup_cosine

# %%
class WarmUpCosine(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(
        self, learning_rate_base, total_steps, warmup_learning_rate, warmup_steps
    ):
        super(WarmUpCosine, self).__init__()

        self.learning_rate_base = learning_rate_base
        self.total_steps = total_steps
        self.warmup_learning_rate = warmup_learning_rate
        self.warmup_steps = warmup_steps
        self.pi = tf.constant(np.pi)

    def __call__(self, step):
        if self.total_steps < self.warmup_steps:
            raise ValueError("Total_steps must be larger or equal to warmup_steps.")

        cos_annealed_lr = tf.cos(
            self.pi
            * (tf.cast(step, tf.float32) - self.warmup_steps)
            / float(self.total_steps - self.warmup_steps)
        )
        learning_rate = 0.5 * self.learning_rate_base * (1 + cos_annealed_lr)

        if self.warmup_steps > 0:
            if self.learning_rate_base < self.warmup_learning_rate:
                raise ValueError(
                    "Learning_rate_base must be larger or equal to "
                    "warmup_learning_rate."
                )
            slope = (
                self.learning_rate_base - self.warmup_learning_rate
            ) / self.warmup_steps
            warmup_rate = slope * tf.cast(step, tf.float32) + self.warmup_learning_rate
            learning_rate = tf.where(
                step < self.warmup_steps, warmup_rate, learning_rate
            )
        return tf.where(
            step > self.total_steps, 0.0, learning_rate, name="learning_rate"
        )

# %% [markdown]
# # 컴파일 및 훈련

# %%
def run_experiment(model):
    total_steps = int((len(x_train) / BATCH_SIZE) * EPOCHS)
    warmup_epoch_percentage = 0.10
    warmup_steps = int(total_steps * warmup_epoch_percentage)
    scheduled_lrs = WarmUpCosine(
        learning_rate_base=LEARNING_RATE,
        total_steps=total_steps,
        warmup_learning_rate=0.0,
        warmup_steps=warmup_steps,
    )

    optimizer = tfa.optimizers.AdamW(
        learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_split=0.1,
    )
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history

# %%
# Run experiments with the vanilla ViT
vit = create_vit_classifier(vanilla=True)
history = run_experiment(vit)
# Out:
# Epoch 1/50
# 704/704 [==============================] - 87s 113ms/step - loss: 4.4710 - accuracy: 0.0383 - top-5-accuracy: 0.1470 - val_loss: 3.9557 - val_accuracy: 0.0928 - val_top-5-accuracy: 0.2938
# Epoch 2/50
# 704/704 [==============================] - 79s 112ms/step - loss: 4.0028 - accuracy: 0.0827 - top-5-accuracy: 0.2667 - val_loss: 3.6857 - val_accuracy: 0.1340 - val_top-5-accuracy: 0.3770
# Epoch 3/50
# 704/704 [==============================] - 79s 112ms/step - loss: 3.6930 - accuracy: 0.1275 - top-5-accuracy: 0.3639 - val_loss: 3.2826 - val_accuracy: 0.2032 - val_top-5-accuracy: 0.4840
# Epoch 4/50
# 704/704 [==============================] - 83s 119ms/step - loss: 3.4443 - accuracy: 0.1711 - top-5-accuracy: 0.4378 - val_loss: 3.1205 - val_accuracy: 0.2264 - val_top-5-accuracy: 0.5258
# Epoch 5/50
# 704/704 [==============================] - 79s 113ms/step - loss: 3.2558 - accuracy: 0.2075 - top-5-accuracy: 0.4918 - val_loss: 2.9311 - val_accuracy: 0.2732 - val_top-5-accuracy: 0.5772
# Epoch 6/50
# 704/704 [==============================] - 79s 112ms/step - loss: 3.0944 - accuracy: 0.2378 - top-5-accuracy: 0.5347 - val_loss: 2.8033 - val_accuracy: 0.2920 - val_top-5-accuracy: 0.6110
# Epoch 7/50
# 704/704 [==============================] - 79s 112ms/step - loss: 2.9461 - accuracy: 0.2665 - top-5-accuracy: 0.5719 - val_loss: 2.7001 - val_accuracy: 0.3200 - val_top-5-accuracy: 0.6248
# Epoch 8/50
# 704/704 [==============================] - 79s 112ms/step - loss: 2.8408 - accuracy: 0.2900 - top-5-accuracy: 0.5965 - val_loss: 2.6252 - val_accuracy: 0.3364 - val_top-5-accuracy: 0.6454
# Epoch 9/50
# 704/704 [==============================] - 79s 112ms/step - loss: 2.7460 - accuracy: 0.3065 - top-5-accuracy: 0.6197 - val_loss: 2.4993 - val_accuracy: 0.3602 - val_top-5-accuracy: 0.6706
# Epoch 10/50
# 704/704 [==============================] - 80s 113ms/step - loss: 2.6653 - accuracy: 0.3254 - top-5-accuracy: 0.6363 - val_loss: 2.4281 - val_accuracy: 0.3774 - val_top-5-accuracy: 0.6922
# Epoch 11/50
# 704/704 [==============================] - 79s 113ms/step - loss: 2.5993 - accuracy: 0.3390 - top-5-accuracy: 0.6520 - val_loss: 2.3759 - val_accuracy: 0.3818 - val_top-5-accuracy: 0.6940
# Epoch 12/50
# 704/704 [==============================] - 79s 113ms/step - loss: 2.5393 - accuracy: 0.3529 - top-5-accuracy: 0.6633 - val_loss: 2.3628 - val_accuracy: 0.3902 - val_top-5-accuracy: 0.6924
# Epoch 13/50
# 704/704 [==============================] - 80s 113ms/step - loss: 2.4915 - accuracy: 0.3600 - top-5-accuracy: 0.6750 - val_loss: 2.3472 - val_accuracy: 0.3952 - val_top-5-accuracy: 0.6966
# Epoch 14/50
# 704/704 [==============================] - 80s 114ms/step - loss: 2.4408 - accuracy: 0.3710 - top-5-accuracy: 0.6848 - val_loss: 2.2944 - val_accuracy: 0.4112 - val_top-5-accuracy: 0.7118
# Epoch 15/50
# 704/704 [==============================] - 80s 113ms/step - loss: 2.3993 - accuracy: 0.3798 - top-5-accuracy: 0.6937 - val_loss: 2.2799 - val_accuracy: 0.4080 - val_top-5-accuracy: 0.7132
# Epoch 16/50
# 704/704 [==============================] - 80s 113ms/step - loss: 2.3491 - accuracy: 0.3886 - top-5-accuracy: 0.7042 - val_loss: 2.2422 - val_accuracy: 0.4206 - val_top-5-accuracy: 0.7170
# Epoch 17/50
# 704/704 [==============================] - 80s 113ms/step - loss: 2.3222 - accuracy: 0.3987 - top-5-accuracy: 0.7093 - val_loss: 2.2056 - val_accuracy: 0.4226 - val_top-5-accuracy: 0.7268
# Epoch 18/50
# 704/704 [==============================] - 80s 113ms/step - loss: 2.2951 - accuracy: 0.4016 - top-5-accuracy: 0.7155 - val_loss: 2.2169 - val_accuracy: 0.4202 - val_top-5-accuracy: 0.7224
# Epoch 19/50
# 704/704 [==============================] - 79s 113ms/step - loss: 2.2582 - accuracy: 0.4083 - top-5-accuracy: 0.7239 - val_loss: 2.2126 - val_accuracy: 0.4242 - val_top-5-accuracy: 0.7280
# Epoch 20/50
# 704/704 [==============================] - 80s 113ms/step - loss: 2.2271 - accuracy: 0.4143 - top-5-accuracy: 0.7286 - val_loss: 2.1817 - val_accuracy: 0.4320 - val_top-5-accuracy: 0.7354
# Epoch 21/50
# 704/704 [==============================] - 80s 114ms/step - loss: 2.2122 - accuracy: 0.4222 - top-5-accuracy: 0.7314 - val_loss: 2.1121 - val_accuracy: 0.4492 - val_top-5-accuracy: 0.7458
# Epoch 22/50
# 704/704 [==============================] - 80s 113ms/step - loss: 2.1700 - accuracy: 0.4268 - top-5-accuracy: 0.7409 - val_loss: 2.1423 - val_accuracy: 0.4514 - val_top-5-accuracy: 0.7358
# Epoch 23/50
# 704/704 [==============================] - 80s 113ms/step - loss: 2.1502 - accuracy: 0.4365 - top-5-accuracy: 0.7444 - val_loss: 2.0815 - val_accuracy: 0.4530 - val_top-5-accuracy: 0.7560
# Epoch 24/50
# 704/704 [==============================] - 80s 113ms/step - loss: 2.1209 - accuracy: 0.4404 - top-5-accuracy: 0.7512 - val_loss: 2.0980 - val_accuracy: 0.4450 - val_top-5-accuracy: 0.7546
# Epoch 25/50
# 704/704 [==============================] - 80s 114ms/step - loss: 2.1019 - accuracy: 0.4450 - top-5-accuracy: 0.7541 - val_loss: 2.1345 - val_accuracy: 0.4378 - val_top-5-accuracy: 0.7422
# Epoch 26/50
# 704/704 [==============================] - 80s 114ms/step - loss: 2.0706 - accuracy: 0.4519 - top-5-accuracy: 0.7631 - val_loss: 2.1243 - val_accuracy: 0.4536 - val_top-5-accuracy: 0.7376
# Epoch 27/50
# 704/704 [==============================] - 80s 113ms/step - loss: 2.0528 - accuracy: 0.4552 - top-5-accuracy: 0.7632 - val_loss: 2.0427 - val_accuracy: 0.4662 - val_top-5-accuracy: 0.7562
# Epoch 28/50
# 704/704 [==============================] - 80s 114ms/step - loss: 2.0314 - accuracy: 0.4597 - top-5-accuracy: 0.7675 - val_loss: 2.0735 - val_accuracy: 0.4602 - val_top-5-accuracy: 0.7532
# Epoch 29/50
# 704/704 [==============================] - 80s 113ms/step - loss: 2.0133 - accuracy: 0.4625 - top-5-accuracy: 0.7750 - val_loss: 2.0697 - val_accuracy: 0.4576 - val_top-5-accuracy: 0.7524
# Epoch 30/50
# 704/704 [==============================] - 80s 113ms/step - loss: 1.9921 - accuracy: 0.4664 - top-5-accuracy: 0.7790 - val_loss: 2.0364 - val_accuracy: 0.4626 - val_top-5-accuracy: 0.7582
# Epoch 31/50
# 704/704 [==============================] - 79s 112ms/step - loss: 1.9709 - accuracy: 0.4745 - top-5-accuracy: 0.7809 - val_loss: 2.0253 - val_accuracy: 0.4660 - val_top-5-accuracy: 0.7662
# Epoch 32/50
# 704/704 [==============================] - 79s 112ms/step - loss: 1.9391 - accuracy: 0.4773 - top-5-accuracy: 0.7868 - val_loss: 2.0375 - val_accuracy: 0.4694 - val_top-5-accuracy: 0.7592
# Epoch 33/50
# 704/704 [==============================] - 80s 113ms/step - loss: 1.9312 - accuracy: 0.4804 - top-5-accuracy: 0.7873 - val_loss: 1.9801 - val_accuracy: 0.4810 - val_top-5-accuracy: 0.7704
# Epoch 34/50
# 704/704 [==============================] - 79s 113ms/step - loss: 1.9196 - accuracy: 0.4846 - top-5-accuracy: 0.7910 - val_loss: 1.9758 - val_accuracy: 0.4824 - val_top-5-accuracy: 0.7732
# Epoch 35/50
# 704/704 [==============================] - 79s 113ms/step - loss: 1.8838 - accuracy: 0.4899 - top-5-accuracy: 0.7961 - val_loss: 1.9875 - val_accuracy: 0.4854 - val_top-5-accuracy: 0.7712
# Epoch 36/50
# 704/704 [==============================] - 80s 113ms/step - loss: 1.8757 - accuracy: 0.4957 - top-5-accuracy: 0.7986 - val_loss: 2.0150 - val_accuracy: 0.4776 - val_top-5-accuracy: 0.7644
# Epoch 37/50
# 704/704 [==============================] - 79s 112ms/step - loss: 1.8608 - accuracy: 0.4966 - top-5-accuracy: 0.8008 - val_loss: 1.9586 - val_accuracy: 0.4862 - val_top-5-accuracy: 0.7770
# Epoch 38/50
# 704/704 [==============================] - 79s 112ms/step - loss: 1.8539 - accuracy: 0.4983 - top-5-accuracy: 0.8035 - val_loss: 1.9598 - val_accuracy: 0.4814 - val_top-5-accuracy: 0.7760
# Epoch 39/50
# 704/704 [==============================] - 79s 112ms/step - loss: 1.8299 - accuracy: 0.5040 - top-5-accuracy: 0.8069 - val_loss: 1.9611 - val_accuracy: 0.4796 - val_top-5-accuracy: 0.7772
# Epoch 40/50
# 704/704 [==============================] - 79s 112ms/step - loss: 1.8202 - accuracy: 0.5068 - top-5-accuracy: 0.8076 - val_loss: 1.9475 - val_accuracy: 0.4860 - val_top-5-accuracy: 0.7802
# Epoch 41/50
# 704/704 [==============================] - 79s 112ms/step - loss: 1.8227 - accuracy: 0.5056 - top-5-accuracy: 0.8089 - val_loss: 1.9551 - val_accuracy: 0.4914 - val_top-5-accuracy: 0.7734
# Epoch 42/50
# 704/704 [==============================] - 79s 113ms/step - loss: 1.8049 - accuracy: 0.5084 - top-5-accuracy: 0.8121 - val_loss: 1.9116 - val_accuracy: 0.4938 - val_top-5-accuracy: 0.7890
# Epoch 43/50
# 704/704 [==============================] - 79s 113ms/step - loss: 1.7938 - accuracy: 0.5133 - top-5-accuracy: 0.8140 - val_loss: 1.9145 - val_accuracy: 0.4876 - val_top-5-accuracy: 0.7826
# Epoch 44/50
# 704/704 [==============================] - 80s 113ms/step - loss: 1.7750 - accuracy: 0.5138 - top-5-accuracy: 0.8206 - val_loss: 1.9295 - val_accuracy: 0.4920 - val_top-5-accuracy: 0.7830
# Epoch 45/50
# 704/704 [==============================] - 80s 114ms/step - loss: 1.7697 - accuracy: 0.5210 - top-5-accuracy: 0.8181 - val_loss: 1.9164 - val_accuracy: 0.4942 - val_top-5-accuracy: 0.7854
# Epoch 46/50
# 704/704 [==============================] - 80s 113ms/step - loss: 1.7587 - accuracy: 0.5196 - top-5-accuracy: 0.8198 - val_loss: 1.9739 - val_accuracy: 0.4812 - val_top-5-accuracy: 0.7798
# Epoch 47/50
# 704/704 [==============================] - 80s 113ms/step - loss: 1.7412 - accuracy: 0.5238 - top-5-accuracy: 0.8232 - val_loss: 1.9471 - val_accuracy: 0.4910 - val_top-5-accuracy: 0.7808
# Epoch 48/50
# 704/704 [==============================] - 80s 113ms/step - loss: 1.7327 - accuracy: 0.5268 - top-5-accuracy: 0.8232 - val_loss: 1.9014 - val_accuracy: 0.4988 - val_top-5-accuracy: 0.7910
# Epoch 49/50
# 704/704 [==============================] - 79s 113ms/step - loss: 1.7326 - accuracy: 0.5283 - top-5-accuracy: 0.8231 - val_loss: 1.9407 - val_accuracy: 0.4876 - val_top-5-accuracy: 0.7822
# Epoch 50/50
# 704/704 [==============================] - 79s 112ms/step - loss: 1.7197 - accuracy: 0.5302 - top-5-accuracy: 0.8276 - val_loss: 1.8809 - val_accuracy: 0.5054 - val_top-5-accuracy: 0.7896
# 157/157 [==============================] - 5s 29ms/step - loss: 1.8379 - accuracy: 0.5099 - top-5-accuracy: 0.7941
# Test accuracy: 50.99%
# Test top 5 accuracy: 79.41%

# %%
vit_sl = create_vit_classifier(vanilla=False)
history = run_experiment(vit_sl)
# Out:
# Epoch 1/50
# 704/704 [==============================] - 93s 121ms/step - loss: 4.4562 - accuracy: 0.0404 - top-5-accuracy: 0.1509 - val_loss: 3.9733 - val_accuracy: 0.0792 - val_top-5-accuracy: 0.2886
# Epoch 2/50
# 704/704 [==============================] - 85s 121ms/step - loss: 4.0331 - accuracy: 0.0791 - top-5-accuracy: 0.2600 - val_loss: 3.7172 - val_accuracy: 0.1324 - val_top-5-accuracy: 0.3680
# Epoch 3/50
# 704/704 [==============================] - 85s 121ms/step - loss: 3.8274 - accuracy: 0.1131 - top-5-accuracy: 0.3280 - val_loss: 3.5223 - val_accuracy: 0.1692 - val_top-5-accuracy: 0.4224
# Epoch 4/50
# 704/704 [==============================] - 84s 120ms/step - loss: 3.6128 - accuracy: 0.1510 - top-5-accuracy: 0.3929 - val_loss: 3.2664 - val_accuracy: 0.2192 - val_top-5-accuracy: 0.4878
# Epoch 5/50
# 704/704 [==============================] - 84s 120ms/step - loss: 3.4372 - accuracy: 0.1808 - top-5-accuracy: 0.4406 - val_loss: 3.0987 - val_accuracy: 0.2500 - val_top-5-accuracy: 0.5246
# Epoch 6/50
# 704/704 [==============================] - 85s 120ms/step - loss: 3.2800 - accuracy: 0.2053 - top-5-accuracy: 0.4842 - val_loss: 2.9643 - val_accuracy: 0.2650 - val_top-5-accuracy: 0.5668
# Epoch 7/50
# 704/704 [==============================] - 84s 119ms/step - loss: 3.1299 - accuracy: 0.2324 - top-5-accuracy: 0.5212 - val_loss: 2.8364 - val_accuracy: 0.2892 - val_top-5-accuracy: 0.5958
# Epoch 8/50
# 704/704 [==============================] - 84s 119ms/step - loss: 2.9879 - accuracy: 0.2588 - top-5-accuracy: 0.5572 - val_loss: 2.7734 - val_accuracy: 0.3022 - val_top-5-accuracy: 0.6034
# Epoch 9/50
# 704/704 [==============================] - 84s 119ms/step - loss: 2.8703 - accuracy: 0.2819 - top-5-accuracy: 0.5845 - val_loss: 2.5847 - val_accuracy: 0.3364 - val_top-5-accuracy: 0.6472
# Epoch 10/50
# 704/704 [==============================] - 84s 120ms/step - loss: 2.7580 - accuracy: 0.3032 - top-5-accuracy: 0.6108 - val_loss: 2.6432 - val_accuracy: 0.3342 - val_top-5-accuracy: 0.6358
# Epoch 11/50
# 704/704 [==============================] - 84s 120ms/step - loss: 2.6806 - accuracy: 0.3217 - top-5-accuracy: 0.6306 - val_loss: 2.4390 - val_accuracy: 0.3730 - val_top-5-accuracy: 0.6786
# Epoch 12/50
# 704/704 [==============================] - 85s 121ms/step - loss: 2.5943 - accuracy: 0.3375 - top-5-accuracy: 0.6506 - val_loss: 2.3582 - val_accuracy: 0.3866 - val_top-5-accuracy: 0.6952
# Epoch 13/50
# 704/704 [==============================] - 85s 121ms/step - loss: 2.5332 - accuracy: 0.3510 - top-5-accuracy: 0.6642 - val_loss: 2.3893 - val_accuracy: 0.3834 - val_top-5-accuracy: 0.6830
# Epoch 14/50
# 704/704 [==============================] - 86s 121ms/step - loss: 2.4628 - accuracy: 0.3632 - top-5-accuracy: 0.6783 - val_loss: 2.2240 - val_accuracy: 0.4266 - val_top-5-accuracy: 0.7252
# Epoch 15/50
# 704/704 [==============================] - 85s 121ms/step - loss: 2.4108 - accuracy: 0.3730 - top-5-accuracy: 0.6919 - val_loss: 2.2505 - val_accuracy: 0.4176 - val_top-5-accuracy: 0.7238
# Epoch 16/50
# 704/704 [==============================] - 85s 121ms/step - loss: 2.3471 - accuracy: 0.3878 - top-5-accuracy: 0.7045 - val_loss: 2.2035 - val_accuracy: 0.4258 - val_top-5-accuracy: 0.7276
# Epoch 17/50
# 704/704 [==============================] - 85s 121ms/step - loss: 2.3137 - accuracy: 0.3952 - top-5-accuracy: 0.7098 - val_loss: 2.1720 - val_accuracy: 0.4266 - val_top-5-accuracy: 0.7396
# Epoch 18/50
# 704/704 [==============================] - 84s 120ms/step - loss: 2.2496 - accuracy: 0.4119 - top-5-accuracy: 0.7221 - val_loss: 2.1120 - val_accuracy: 0.4380 - val_top-5-accuracy: 0.7508
# Epoch 19/50
# 704/704 [==============================] - 83s 118ms/step - loss: 2.2139 - accuracy: 0.4155 - top-5-accuracy: 0.7314 - val_loss: 2.1009 - val_accuracy: 0.4444 - val_top-5-accuracy: 0.7478
# Epoch 20/50
# 704/704 [==============================] - 83s 118ms/step - loss: 2.1711 - accuracy: 0.4275 - top-5-accuracy: 0.7401 - val_loss: 2.1000 - val_accuracy: 0.4510 - val_top-5-accuracy: 0.7488
# Epoch 21/50
# 704/704 [==============================] - 83s 118ms/step - loss: 2.1426 - accuracy: 0.4338 - top-5-accuracy: 0.7455 - val_loss: 2.0651 - val_accuracy: 0.4538 - val_top-5-accuracy: 0.7616
# Epoch 22/50
# 704/704 [==============================] - 85s 120ms/step - loss: 2.1047 - accuracy: 0.4412 - top-5-accuracy: 0.7547 - val_loss: 2.0169 - val_accuracy: 0.4608 - val_top-5-accuracy: 0.7600
# Epoch 23/50
# 704/704 [==============================] - 85s 121ms/step - loss: 2.0727 - accuracy: 0.4473 - top-5-accuracy: 0.7578 - val_loss: 2.0138 - val_accuracy: 0.4564 - val_top-5-accuracy: 0.7670
# Epoch 24/50
# 704/704 [==============================] - 85s 121ms/step - loss: 2.0450 - accuracy: 0.4537 - top-5-accuracy: 0.7638 - val_loss: 2.0039 - val_accuracy: 0.4592 - val_top-5-accuracy: 0.7684
# Epoch 25/50
# 704/704 [==============================] - 85s 121ms/step - loss: 2.0175 - accuracy: 0.4568 - top-5-accuracy: 0.7688 - val_loss: 1.9439 - val_accuracy: 0.4732 - val_top-5-accuracy: 0.7820
# Epoch 26/50
# 704/704 [==============================] - 84s 120ms/step - loss: 1.9890 - accuracy: 0.4659 - top-5-accuracy: 0.7757 - val_loss: 1.9461 - val_accuracy: 0.4792 - val_top-5-accuracy: 0.7890
# Epoch 27/50
# 704/704 [==============================] - 84s 119ms/step - loss: 1.9661 - accuracy: 0.4727 - top-5-accuracy: 0.7815 - val_loss: 1.9748 - val_accuracy: 0.4678 - val_top-5-accuracy: 0.7738
# Epoch 28/50
# 704/704 [==============================] - 84s 119ms/step - loss: 1.9448 - accuracy: 0.4762 - top-5-accuracy: 0.7845 - val_loss: 1.9240 - val_accuracy: 0.4910 - val_top-5-accuracy: 0.7820
# Epoch 29/50
# 704/704 [==============================] - 84s 119ms/step - loss: 1.9302 - accuracy: 0.4779 - top-5-accuracy: 0.7877 - val_loss: 1.9424 - val_accuracy: 0.4778 - val_top-5-accuracy: 0.7810
# Epoch 30/50
# 704/704 [==============================] - 84s 119ms/step - loss: 1.9147 - accuracy: 0.4837 - top-5-accuracy: 0.7896 - val_loss: 1.8947 - val_accuracy: 0.4866 - val_top-5-accuracy: 0.7834
# Epoch 31/50
# 704/704 [==============================] - 84s 119ms/step - loss: 1.9000 - accuracy: 0.4876 - top-5-accuracy: 0.7924 - val_loss: 1.9021 - val_accuracy: 0.4892 - val_top-5-accuracy: 0.7874
# Epoch 32/50
# 704/704 [==============================] - 85s 120ms/step - loss: 1.8855 - accuracy: 0.4922 - top-5-accuracy: 0.7938 - val_loss: 1.8701 - val_accuracy: 0.5006 - val_top-5-accuracy: 0.7960
# Epoch 33/50
# 704/704 [==============================] - 85s 121ms/step - loss: 1.8651 - accuracy: 0.4951 - top-5-accuracy: 0.7992 - val_loss: 1.8605 - val_accuracy: 0.5052 - val_top-5-accuracy: 0.7902
# Epoch 34/50
# 704/704 [==============================] - 85s 121ms/step - loss: 1.8585 - accuracy: 0.4974 - top-5-accuracy: 0.7997 - val_loss: 1.8745 - val_accuracy: 0.4928 - val_top-5-accuracy: 0.7902
# Epoch 35/50
# 704/704 [==============================] - 84s 119ms/step - loss: 1.8293 - accuracy: 0.5040 - top-5-accuracy: 0.8057 - val_loss: 1.9103 - val_accuracy: 0.4920 - val_top-5-accuracy: 0.7768
# Epoch 36/50
# 704/704 [==============================] - 85s 120ms/step - loss: 1.8239 - accuracy: 0.5035 - top-5-accuracy: 0.8068 - val_loss: 1.9078 - val_accuracy: 0.4932 - val_top-5-accuracy: 0.7914
# Epoch 37/50
# 704/704 [==============================] - 85s 121ms/step - loss: 1.8132 - accuracy: 0.5047 - top-5-accuracy: 0.8070 - val_loss: 1.8521 - val_accuracy: 0.5036 - val_top-5-accuracy: 0.7954
# Epoch 38/50
# 704/704 [==============================] - 85s 121ms/step - loss: 1.7992 - accuracy: 0.5099 - top-5-accuracy: 0.8100 - val_loss: 1.8191 - val_accuracy: 0.5118 - val_top-5-accuracy: 0.8040
# Epoch 39/50
# 704/704 [==============================] - 85s 121ms/step - loss: 1.7905 - accuracy: 0.5115 - top-5-accuracy: 0.8143 - val_loss: 1.8145 - val_accuracy: 0.5066 - val_top-5-accuracy: 0.8082
# Epoch 40/50
# 704/704 [==============================] - 84s 120ms/step - loss: 1.7746 - accuracy: 0.5152 - top-5-accuracy: 0.8162 - val_loss: 1.7976 - val_accuracy: 0.5196 - val_top-5-accuracy: 0.8064
# Epoch 41/50
# 704/704 [==============================] - 84s 119ms/step - loss: 1.7657 - accuracy: 0.5170 - top-5-accuracy: 0.8194 - val_loss: 1.8606 - val_accuracy: 0.5032 - val_top-5-accuracy: 0.7978
# Epoch 42/50
# 704/704 [==============================] - 84s 119ms/step - loss: 1.7628 - accuracy: 0.5202 - top-5-accuracy: 0.8192 - val_loss: 1.8813 - val_accuracy: 0.5014 - val_top-5-accuracy: 0.7880
# Epoch 43/50
# 704/704 [==============================] - 85s 120ms/step - loss: 1.7480 - accuracy: 0.5246 - top-5-accuracy: 0.8212 - val_loss: 1.8012 - val_accuracy: 0.5208 - val_top-5-accuracy: 0.8066
# Epoch 44/50
# 704/704 [==============================] - 85s 121ms/step - loss: 1.7397 - accuracy: 0.5270 - top-5-accuracy: 0.8224 - val_loss: 1.8131 - val_accuracy: 0.5134 - val_top-5-accuracy: 0.8108
# Epoch 45/50
# 704/704 [==============================] - 86s 122ms/step - loss: 1.7250 - accuracy: 0.5288 - top-5-accuracy: 0.8248 - val_loss: 1.7687 - val_accuracy: 0.5130 - val_top-5-accuracy: 0.8130
# Epoch 46/50
# 704/704 [==============================] - 85s 121ms/step - loss: 1.7208 - accuracy: 0.5317 - top-5-accuracy: 0.8253 - val_loss: 1.8411 - val_accuracy: 0.5110 - val_top-5-accuracy: 0.7994
# Epoch 47/50
# 704/704 [==============================] - 85s 121ms/step - loss: 1.7145 - accuracy: 0.5330 - top-5-accuracy: 0.8264 - val_loss: 1.7913 - val_accuracy: 0.5240 - val_top-5-accuracy: 0.8068
# Epoch 48/50
# 704/704 [==============================] - 85s 121ms/step - loss: 1.6956 - accuracy: 0.5343 - top-5-accuracy: 0.8306 - val_loss: 1.8266 - val_accuracy: 0.5106 - val_top-5-accuracy: 0.8040
# Epoch 49/50
# 704/704 [==============================] - 85s 121ms/step - loss: 1.6902 - accuracy: 0.5352 - top-5-accuracy: 0.8315 - val_loss: 1.7885 - val_accuracy: 0.5228 - val_top-5-accuracy: 0.8082
# Epoch 50/50
# 704/704 [==============================] - 85s 121ms/step - loss: 1.6834 - accuracy: 0.5372 - top-5-accuracy: 0.8323 - val_loss: 1.8302 - val_accuracy: 0.5164 - val_top-5-accuracy: 0.8048
# 157/157 [==============================] - 5s 33ms/step - loss: 1.8052 - accuracy: 0.5206 - top-5-accuracy: 0.7996
# Test accuracy: 52.06%
# Test top 5 accuracy: 79.96%
