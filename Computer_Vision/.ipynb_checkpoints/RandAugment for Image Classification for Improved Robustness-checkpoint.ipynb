# %% [markdown]
# RandAugment: Practical automated data augmentation with a reduced search space - [pdf](https://arxiv.org/pdf/1909.13719.pdf)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 준비

# %% [markdown]
# ## 라이브러리 및 세팅

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers
import tensorflow_datasets as tfds
from imgaug import augmenters as iaa
import imgaug as ia

tfds.disable_progress_bar()
tf.random.set_seed(42)
ia.seed(42)

# %% [markdown]
# ## 데이터

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
print(f"Total training examples: {len(x_train)}")
print(f"Total test examples: {len(x_test)}")
# Out:
# Total training examples: 50000
# Total test examples: 10000

# %% [markdown]
# ## 하이퍼 파라미터

# %%
AUTO = tf.data.AUTOTUNE
BATCH_SIZE = 128
EPOCHS = 30
IMAGE_SIZE = 72

# %% [markdown]
# ## 데이터 셋

# %%
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(BATCH_SIZE * 100).batch(BATCH_SIZE).map(
        lambda x, y: (tf.image.resize(x, (IMAGE_SIZE, IMAGE_SIZE)), y),
        num_parallel_calls=AUTO,
    ).prefetch(AUTO)

test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH_SIZE).map(
        lambda x, y: (tf.image.resize(x, (IMAGE_SIZE, IMAGE_SIZE)), y),
        num_parallel_calls=AUTO,
    ).prefetch(AUTO)

# %% [markdown]
# ## 데이터 셋 샘플

# %%
sample_images, _ = next(iter(train_ds))
plt.figure(figsize=(10, 10))
for i, image in enumerate(sample_images[:9]):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image.numpy().astype("int"))
    plt.axis("off")

# %% [markdown]
# # 증강

# %% [markdown]
# ## Random Aug

# %%
rand_aug = iaa.RandAugment(n=3, m=7)

def augment(images):
    images = tf.cast(images, tf.uint8)
    return rand_aug(images=images.numpy())

# %%
train_ds_rand = (tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(BATCH_SIZE * 100).batch(BATCH_SIZE).map(
        lambda x, y: (tf.image.resize(x, (IMAGE_SIZE, IMAGE_SIZE)), y),
        num_parallel_calls=AUTO,
    ).map(
        lambda x, y: (tf.py_function(augment, [x], [tf.float32])[0], y),
        num_parallel_calls=AUTO,
    ).prefetch(AUTO))

# %% [markdown]
# ### Random Aug 샘플

# %%
sample_images, _ = next(iter(train_ds_rand))
plt.figure(figsize=(10, 10))
for i, image in enumerate(sample_images[:9]):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image.numpy().astype("int"))
    plt.axis("off")

# %% [markdown]
# ## Simple Aug

# %%
simple_aug = tf.keras.Sequential([
    layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(factor=0.02),
    layers.RandomZoom(height_factor=0.2, width_factor=0.2),
])

# Now, map the augmentation pipeline to our training dataset
train_ds_simple = (tf.data.Dataset.from_tensor_slices(
    (x_train, y_train)).shuffle(BATCH_SIZE * 100).batch(BATCH_SIZE).map(
        lambda x, y: (simple_aug(x), y),
        num_parallel_calls=AUTO).prefetch(AUTO))

# %% [markdown]
# ### Simple Aug 샘플

# %%
sample_images, _ = next(iter(train_ds_simple))
plt.figure(figsize=(10, 10))
for i, image in enumerate(sample_images[:9]):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image.numpy().astype("int"))
    plt.axis("off")

# %% [markdown]
# # 훈련

# %% [markdown]
# ## initial_model

# %%
def get_training_model():
    resnet50_v2 = tf.keras.applications.ResNet50V2(
        weights=None,
        include_top=True,
        input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3),
        classes=10,
    )
    model = tf.keras.Sequential(
        [
            layers.Input((IMAGE_SIZE, IMAGE_SIZE, 3)),
            layers.Rescaling(scale=1.0 / 127.5, offset=-1),
            resnet50_v2,
        ]
    )
    return model

get_training_model().summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 72, 72, 3)         0
#
#  resnet50v2 (Functional)     (None, 10)                23585290
#
# =================================================================
# Total params: 23,585,290
# Trainable params: 23,539,850
# Non-trainable params: 45,440
# _________________________________________________________________

# %%
initial_model = get_training_model()
initial_model.save_weights("model/initial_weights.h5")

# %% [markdown]
# ## Random Aug model

# %%
rand_aug_model = get_training_model()
rand_aug_model.load_weights("model/initial_weights.h5")
rand_aug_model.compile(
    loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"]
)
rand_aug_model.fit(train_ds_rand, validation_data=test_ds, epochs=EPOCHS)
_, test_acc = rand_aug_model.evaluate(test_ds)
print("Test accuracy: {:.2f}%".format(test_acc * 100))
# Out:
# Epoch 1/30
# 391/391 [==============================] - 68s 150ms/step - loss: 1.7871 - accuracy: 0.3547 - val_loss: 2.0735 - val_accuracy: 0.3939
# Epoch 2/30
# 391/391 [==============================] - 58s 146ms/step - loss: 1.3681 - accuracy: 0.5126 - val_loss: 1.5081 - val_accuracy: 0.5019
# Epoch 3/30
# 391/391 [==============================] - 58s 148ms/step - loss: 1.1377 - accuracy: 0.6017 - val_loss: 1.9007 - val_accuracy: 0.5491
# Epoch 4/30
# 391/391 [==============================] - 59s 148ms/step - loss: 1.0031 - accuracy: 0.6508 - val_loss: 0.8589 - val_accuracy: 0.7068
# Epoch 5/30
# 391/391 [==============================] - 58s 145ms/step - loss: 0.9024 - accuracy: 0.6859 - val_loss: 0.8446 - val_accuracy: 0.7155
# Epoch 6/30
# 391/391 [==============================] - 59s 148ms/step - loss: 0.8348 - accuracy: 0.7118 - val_loss: 0.6936 - val_accuracy: 0.7620
# Epoch 7/30
# 391/391 [==============================] - 60s 152ms/step - loss: 0.7826 - accuracy: 0.7289 - val_loss: 0.7527 - val_accuracy: 0.7510
# Epoch 8/30
# 391/391 [==============================] - 58s 148ms/step - loss: 0.7279 - accuracy: 0.7494 - val_loss: 0.5989 - val_accuracy: 0.7928
# Epoch 9/30
# 391/391 [==============================] - 59s 146ms/step - loss: 0.6887 - accuracy: 0.7609 - val_loss: 0.6185 - val_accuracy: 0.7899
# Epoch 10/30
# 391/391 [==============================] - 58s 145ms/step - loss: 0.6507 - accuracy: 0.7725 - val_loss: 0.5763 - val_accuracy: 0.8037
# Epoch 11/30
# 391/391 [==============================] - 58s 145ms/step - loss: 0.6228 - accuracy: 0.7856 - val_loss: 0.5932 - val_accuracy: 0.8026
# Epoch 12/30
# 391/391 [==============================] - 58s 148ms/step - loss: 0.5889 - accuracy: 0.7968 - val_loss: 0.6046 - val_accuracy: 0.7969
# Epoch 13/30
# 391/391 [==============================] - 58s 147ms/step - loss: 0.5643 - accuracy: 0.8067 - val_loss: 0.5488 - val_accuracy: 0.8225
# Epoch 14/30
# 391/391 [==============================] - 58s 147ms/step - loss: 0.5404 - accuracy: 0.8136 - val_loss: 0.6097 - val_accuracy: 0.8023
# Epoch 15/30
# 391/391 [==============================] - 58s 148ms/step - loss: 0.5218 - accuracy: 0.8224 - val_loss: 0.5366 - val_accuracy: 0.8235
# Epoch 16/30
# 391/391 [==============================] - 59s 149ms/step - loss: 0.4974 - accuracy: 0.8281 - val_loss: 0.6411 - val_accuracy: 0.7920
# Epoch 17/30
# 391/391 [==============================] - 59s 147ms/step - loss: 0.4798 - accuracy: 0.8339 - val_loss: 0.4431 - val_accuracy: 0.8512
# Epoch 18/30
# 391/391 [==============================] - 61s 154ms/step - loss: 0.4608 - accuracy: 0.8397 - val_loss: 0.5169 - val_accuracy: 0.8304
# Epoch 19/30
# 391/391 [==============================] - 59s 147ms/step - loss: 0.4457 - accuracy: 0.8467 - val_loss: 0.5186 - val_accuracy: 0.8279
# Epoch 20/30
# 391/391 [==============================] - 59s 149ms/step - loss: 0.4337 - accuracy: 0.8511 - val_loss: 0.4941 - val_accuracy: 0.8384
# Epoch 21/30
# 391/391 [==============================] - 64s 159ms/step - loss: 0.4402 - accuracy: 0.8487 - val_loss: 0.5073 - val_accuracy: 0.8366
# Epoch 22/30
# 391/391 [==============================] - 59s 150ms/step - loss: 0.4022 - accuracy: 0.8608 - val_loss: 0.4129 - val_accuracy: 0.8609
# Epoch 23/30
# 391/391 [==============================] - 59s 147ms/step - loss: 0.3830 - accuracy: 0.8672 - val_loss: 0.4698 - val_accuracy: 0.8480
# Epoch 24/30
# 391/391 [==============================] - 60s 150ms/step - loss: 0.3701 - accuracy: 0.8708 - val_loss: 0.4191 - val_accuracy: 0.8617
# Epoch 25/30
# 391/391 [==============================] - 58s 146ms/step - loss: 0.3616 - accuracy: 0.8749 - val_loss: 0.4303 - val_accuracy: 0.8542
# Epoch 26/30
# 391/391 [==============================] - 58s 146ms/step - loss: 0.3503 - accuracy: 0.8780 - val_loss: 0.4308 - val_accuracy: 0.8608
# Epoch 27/30
# 391/391 [==============================] - 58s 145ms/step - loss: 0.3391 - accuracy: 0.8805 - val_loss: 0.3968 - val_accuracy: 0.8683
# Epoch 28/30
# 391/391 [==============================] - 58s 146ms/step - loss: 0.3306 - accuracy: 0.8848 - val_loss: 0.4129 - val_accuracy: 0.8674
# Epoch 29/30
# 391/391 [==============================] - 58s 145ms/step - loss: 0.3150 - accuracy: 0.8896 - val_loss: 0.3940 - val_accuracy: 0.8753
# Epoch 30/30
# 391/391 [==============================] - 58s 145ms/step - loss: 0.3058 - accuracy: 0.8944 - val_loss: 0.4228 - val_accuracy: 0.8643
# 79/79 [==============================] - 3s 40ms/step - loss: 0.4228 - accuracy: 0.8643
# Test accuracy: 86.43%

# %% [markdown]
# ## Simple Aug model

# %%
simple_aug_model = get_training_model()
simple_aug_model.load_weights("model/initial_weights.h5")
simple_aug_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
simple_aug_model.fit(train_ds_simple, validation_data=test_ds, epochs=EPOCHS)
_, test_acc = simple_aug_model.evaluate(test_ds)
print("Test accuracy: {:.2f}%".format(test_acc * 100))
# Out:
# Epoch 1/30
# 391/391 [==============================] - 56s 134ms/step - loss: 1.3814 - accuracy: 0.5031 - val_loss: 1.7171 - val_accuracy: 0.4753
# Epoch 2/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.9584 - accuracy: 0.6604 - val_loss: 1.1636 - val_accuracy: 0.6285
# Epoch 3/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.7337 - accuracy: 0.7427 - val_loss: 1.0321 - val_accuracy: 0.6861
# Epoch 4/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.5733 - accuracy: 0.7988 - val_loss: 1.2456 - val_accuracy: 0.6581
# Epoch 5/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.4618 - accuracy: 0.8397 - val_loss: 0.7769 - val_accuracy: 0.7562
# Epoch 6/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.3665 - accuracy: 0.8723 - val_loss: 0.8651 - val_accuracy: 0.7423
# Epoch 7/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.2830 - accuracy: 0.8988 - val_loss: 0.7822 - val_accuracy: 0.7752
# Epoch 8/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.2223 - accuracy: 0.9205 - val_loss: 0.9806 - val_accuracy: 0.7578
# Epoch 9/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.1764 - accuracy: 0.9383 - val_loss: 0.9831 - val_accuracy: 0.7590
# Epoch 10/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.1508 - accuracy: 0.9476 - val_loss: 1.1962 - val_accuracy: 0.7412
# Epoch 11/30
# 391/391 [==============================] - 52s 134ms/step - loss: 0.1228 - accuracy: 0.9565 - val_loss: 0.9036 - val_accuracy: 0.7872
# Epoch 12/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.1008 - accuracy: 0.9646 - val_loss: 1.0094 - val_accuracy: 0.7887
# Epoch 13/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.0870 - accuracy: 0.9703 - val_loss: 1.0127 - val_accuracy: 0.7811
# Epoch 14/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.0803 - accuracy: 0.9722 - val_loss: 1.0260 - val_accuracy: 0.7872
# Epoch 15/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.0775 - accuracy: 0.9731 - val_loss: 1.1779 - val_accuracy: 0.7689
# Epoch 16/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.0769 - accuracy: 0.9735 - val_loss: 1.1595 - val_accuracy: 0.7725
# Epoch 17/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.0646 - accuracy: 0.9776 - val_loss: 1.1125 - val_accuracy: 0.7845
# Epoch 18/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.0643 - accuracy: 0.9785 - val_loss: 1.2152 - val_accuracy: 0.7710
# Epoch 19/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.0605 - accuracy: 0.9788 - val_loss: 1.0906 - val_accuracy: 0.7802
# Epoch 20/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.0529 - accuracy: 0.9814 - val_loss: 1.2323 - val_accuracy: 0.7641
# Epoch 21/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.0501 - accuracy: 0.9824 - val_loss: 1.2036 - val_accuracy: 0.7762
# Epoch 22/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.0451 - accuracy: 0.9849 - val_loss: 1.2730 - val_accuracy: 0.7729
# Epoch 23/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.0462 - accuracy: 0.9849 - val_loss: 1.0372 - val_accuracy: 0.8017
# Epoch 24/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.0459 - accuracy: 0.9842 - val_loss: 1.1275 - val_accuracy: 0.7977
# Epoch 25/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.0442 - accuracy: 0.9857 - val_loss: 1.0361 - val_accuracy: 0.7977
# Epoch 26/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.0375 - accuracy: 0.9877 - val_loss: 1.0938 - val_accuracy: 0.7889
# Epoch 27/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.0386 - accuracy: 0.9868 - val_loss: 1.0889 - val_accuracy: 0.7964
# Epoch 28/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.0407 - accuracy: 0.9862 - val_loss: 1.2048 - val_accuracy: 0.7883
# Epoch 29/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.0347 - accuracy: 0.9885 - val_loss: 1.0997 - val_accuracy: 0.8033
# Epoch 30/30
# 391/391 [==============================] - 52s 133ms/step - loss: 0.0356 - accuracy: 0.9879 - val_loss: 1.1475 - val_accuracy: 0.7894
# 79/79 [==============================] - 3s 40ms/step - loss: 1.1475 - accuracy: 0.7894
# Test accuracy: 78.94%

# %% [markdown]
# # 평가

# %% [markdown]
# * Randam_augmentation을 사용했을 때 과대 적합이 되는 것을 방지하고 일반화 성능을 올려 최종 val_acc 의 값이 0.08 까지 차이가는 것을 확인할 수 있었다.
