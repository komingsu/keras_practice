# %% [markdown]
# * PAPER - Distilling the Knowledge in a Neural Network - [PDF](https://arxiv.org/pdf/1503.02531.pdf)
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 준비

# %% [markdown]
# ## 라이브러리

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# %% [markdown]
# ## 데이터 셋

# %%
# Prepare the train and test dataset.
batch_size = 64
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Normalize data
x_train = x_train.astype("float32") / 255.0
x_train = np.reshape(x_train, (-1, 28, 28, 1))

x_test = x_test.astype("float32") / 255.0
x_test = np.reshape(x_test, (-1, 28, 28, 1))

# %% [markdown]
# # 모델

# %% [markdown]
# ## Distiller

# %%
class Distiller(keras.Model):
    def __init__(self, student, teacher):
        super(Distiller, self).__init__()
        self.teacher = teacher
        self.student = student

    def compile(
        self,
        optimizer,
        metrics,
        student_loss_fn,
        distillation_loss_fn,
        alpha=0.1,
        temperature=3,
    ):

        super(Distiller, self).compile(optimizer=optimizer, metrics=metrics)
        self.student_loss_fn = student_loss_fn
        self.distillation_loss_fn = distillation_loss_fn
        self.alpha = alpha
        self.temperature = temperature

    def train_step(self, data):
        # Unpack data
        x, y = data

        # Forward pass of teacher
        teacher_predictions = self.teacher(x, training=False)

        with tf.GradientTape() as tape:
            # Forward pass of student
            student_predictions = self.student(x, training=True)

            # Compute losses
            student_loss = self.student_loss_fn(y, student_predictions)

            # Compute scaled distillation loss from https://arxiv.org/abs/1503.02531
            # The magnitudes of the gradients produced by the soft targets scale
            # as 1/T^2, multiply them by T^2 when using both hard and soft targets.
            distillation_loss = (
                self.distillation_loss_fn(
                    tf.nn.softmax(teacher_predictions / self.temperature, axis=1),
                    tf.nn.softmax(student_predictions / self.temperature, axis=1),
                )
                * self.temperature**2
            )

            loss = self.alpha * student_loss + (1 - self.alpha) * distillation_loss

        # Compute gradients
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)

        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        # Update the metrics configured in `compile()`.
        self.compiled_metrics.update_state(y, student_predictions)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update(
            {"student_loss": student_loss, "distillation_loss": distillation_loss}
        )
        return results

    def test_step(self, data):
        # Unpack the data
        x, y = data

        # Compute predictions
        y_prediction = self.student(x, training=False)

        # Calculate the loss
        student_loss = self.student_loss_fn(y, y_prediction)

        # Update the metrics.
        self.compiled_metrics.update_state(y, y_prediction)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update({"student_loss": student_loss})
        return results

# %% [markdown]
# ## teacher, student

# %%
teacher = keras.Sequential(
    [
        keras.Input(shape=(28, 28, 1)),
        layers.Conv2D(256, (3, 3), strides=(2, 2), padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding="same"),
        layers.Conv2D(512, (3, 3), strides=(2, 2), padding="same"),
        layers.Flatten(),
        layers.Dense(10),
    ],
    name="teacher",
)

student = keras.Sequential(
    [
        keras.Input(shape=(28, 28, 1)),
        layers.Conv2D(16, (3, 3), strides=(2, 2), padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding="same"),
        layers.Conv2D(32, (3, 3), strides=(2, 2), padding="same"),
        layers.Flatten(),
        layers.Dense(10),
    ],
    name="student",
)

student_scratch = keras.models.clone_model(student)

# %% [markdown]
# # 훈련

# %% [markdown]
# ## teacher train

# %%
teacher.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
)

# Train and evaluate teacher on data.
teacher.fit(x_train, y_train, epochs=20)
teacher.evaluate(x_test, y_test)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1426 - sparse_categorical_accuracy: 0.9562
# Epoch 2/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0898 - sparse_categorical_accuracy: 0.9730
# Epoch 3/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0801 - sparse_categorical_accuracy: 0.9771
# Epoch 4/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0766 - sparse_categorical_accuracy: 0.9784
# Epoch 5/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0681 - sparse_categorical_accuracy: 0.9811
# Epoch 6/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0642 - sparse_categorical_accuracy: 0.9825
# Epoch 7/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0663 - sparse_categorical_accuracy: 0.9820
# Epoch 8/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0629 - sparse_categorical_accuracy: 0.9842
# Epoch 9/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0600 - sparse_categorical_accuracy: 0.9855
# Epoch 10/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0585 - sparse_categorical_accuracy: 0.9865
# Epoch 11/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0537 - sparse_categorical_accuracy: 0.9875
# Epoch 12/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0658 - sparse_categorical_accuracy: 0.9867
# Epoch 13/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0578 - sparse_categorical_accuracy: 0.9888
# Epoch 14/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0551 - sparse_categorical_accuracy: 0.9889
# Epoch 15/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0561 - sparse_categorical_accuracy: 0.9894
# Epoch 16/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0618 - sparse_categorical_accuracy: 0.9899
# Epoch 17/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0622 - sparse_categorical_accuracy: 0.9901
# Epoch 18/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0582 - sparse_categorical_accuracy: 0.9905
# Epoch 19/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0668 - sparse_categorical_accuracy: 0.9904
# Epoch 20/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0552 - sparse_categorical_accuracy: 0.9918
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3040 - sparse_categorical_accuracy: 0.9785
# [0.30399689078330994, 0.9785000085830688]

# %% [markdown]
# ## teacher to student with distiller

# %%
distiller = Distiller(student=student, teacher=teacher)
distiller.compile(
    optimizer=keras.optimizers.Adam(),
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
    student_loss_fn=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    distillation_loss_fn=keras.losses.KLDivergence(),
    alpha=0.1,
    temperature=10,
)

# Distill teacher to student
distiller.fit(x_train, y_train, epochs=10)

# Evaluate student on test dataset
distiller.evaluate(x_test, y_test)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - sparse_categorical_accuracy: 0.8723 - student_loss: 1.6855 - distillation_loss: 36.4864
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - sparse_categorical_accuracy: 0.9453 - student_loss: 0.7548 - distillation_loss: 14.6739
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - sparse_categorical_accuracy: 0.9684 - student_loss: 0.4011 - distillation_loss: 7.5253
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - sparse_categorical_accuracy: 0.9732 - student_loss: 0.3226 - distillation_loss: 6.0012
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - sparse_categorical_accuracy: 0.9763 - student_loss: 0.2823 - distillation_loss: 5.1109
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - sparse_categorical_accuracy: 0.9779 - student_loss: 0.2557 - distillation_loss: 4.5597
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - sparse_categorical_accuracy: 0.9789 - student_loss: 0.2382 - distillation_loss: 4.1324
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - sparse_categorical_accuracy: 0.9802 - student_loss: 0.2199 - distillation_loss: 3.8018
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - sparse_categorical_accuracy: 0.9807 - student_loss: 0.2087 - distillation_loss: 3.5621
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - sparse_categorical_accuracy: 0.9814 - student_loss: 0.1973 - distillation_loss: 3.3207
# 313/313 [==============================] - 1s 2ms/step - sparse_categorical_accuracy: 0.9791 - student_loss: 0.2454
# [0.9790999889373779, 0.0]

# %% [markdown]
# ## student train alone

# %%
# Train student as doen usually
student_scratch.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
)

# Train and evaluate student trained from scratch.
student_scratch.fit(x_train, y_train, epochs=10)
student_scratch.evaluate(x_test, y_test)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0617 - sparse_categorical_accuracy: 0.9805
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0562 - sparse_categorical_accuracy: 0.9824
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0508 - sparse_categorical_accuracy: 0.9845
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0471 - sparse_categorical_accuracy: 0.9852
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0436 - sparse_categorical_accuracy: 0.9864
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0399 - sparse_categorical_accuracy: 0.9872
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0377 - sparse_categorical_accuracy: 0.9878
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0353 - sparse_categorical_accuracy: 0.9885
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0326 - sparse_categorical_accuracy: 0.9895
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0312 - sparse_categorical_accuracy: 0.9901
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0618 - sparse_categorical_accuracy: 0.9826
# [0.06180083006620407, 0.9825999736785889]
